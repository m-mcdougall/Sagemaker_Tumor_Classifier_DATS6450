# %% [markdown]
# # 1) Introduction of the Dataset

# %% [markdown]
# We decided to work on this Kaggle dataset:
# https://www.kaggle.com/sartajbhuvaji/brain-tumor-classification-mri

# %% [markdown]
# # 2) Setup -- Google Mount, Getting Data from Kaggle, Libraries

# %% [markdown]
# **Mounting Drive**

# %%
from google.colab import drive
import sys
import os

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Getting Data from Kaggle**

# %% [markdown]
# As the datasets get bigger, we wanted to find a way to avoid having to download all the data to our personal computers first, and then uploading it to colab.
#
# This code allows us to downloading the data from Kaggle and save it directly to colab.

# %%
#Before you do this step you have to go to kaggle, log in, click on your picture, go to your account, scroll down to API and click "Create new API token" 
from google.colab import files
files.upload()  #this will prompt you to upload the kaggle.json
# Out:
#      <input type="file" id="files-5f40e2f4-ebcd-44d1-89ab-81496d521f99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f40e2f4-ebcd-44d1-89ab-81496d521f99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kristinlevine","key":"6796f06cb27f1017a724c0eb53b81dbc"}'}

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json  # set permission
# Out:
# kaggle.json

# %%
#This was just looking up the dataset to make sure we had the correct name
# !kaggle datasets list -s Brain
# Out:
# ...
# ref                                                          title                                             size  lastUpdated          downloadCount
# -----------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------
# jakeshbohaju/brain-tumor                                     Brain Tumor                                       14MB  2020-07-26 01:52:35           3416
# mateuszbuda/lgg-mri-segmentation                             Brain MRI segmentation                           714MB  2019-05-02 21:32:45          19276
# navoneel/brain-mri-images-for-brain-tumor-detection          Brain MRI Images for Brain Tumor Detection        15MB  2019-04-14 15:15:54          26376
# sartajbhuvaji/brain-tumor-classification-mri                 Brain Tumor Classification (MRI)                  87MB  2020-05-24 16:24:55           6708
# ...

# %%
#Download dataset
# !kaggle datasets download -d sartajbhuvaji/brain-tumor-classification-mri
# Out:
# ...
#  84% 73.0M/86.8M [00:03<00:00, 16.8MB/s]
# 100% 86.8M/86.8M [00:03<00:00, 27.0MB/s]

# %%
#Unzip and save it wherever you want
# !unzip "/content/brain-tumor-classification-mri" -d "/content/drive/My Drive/Colab Notebooks/Brain_Tumor/"
# Out:
# Archive:  /content/brain-tumor-classification-mri.zip
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(1).jpg
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(10).jpg
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(100).jpg
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(11).jpg
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(12).jpg
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(13).jpg
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(14).jpg
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(15).jpg
#   inflating: /content/drive/My Drive/Colab Notebooks/Brain_Tumor/Testing/glioma_tumor/image(16).jpg
# ...
